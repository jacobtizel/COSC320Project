# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
datanumber = open("./analysis/datanumber2000.js", "r")
iterlistDN = list(250 * x for x in range(1, 41))
timelistDN = json.load(datanumber)
print(iterlistDN)
print(timelistDN)
datanumber.close()
# Out:
# [250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500, 7750, 8000, 8250, 8500, 8750, 9000, 9250, 9500, 9750, 10000]
# [0, 11, 19, 29, 40, 48, 63, 68, 79, 92, 100, 106, 122, 134, 129, 139, 165, 172, 170, 181, 186, 193, 215, 219, 236, 231, 241, 252, 256, 267, 283, 281, 285, 300, 313, 316, 325, 337, 340, 361]

# %%
datasize = open("./analysis/datasize2000.js", "r")
iterlistDS = list(250 * x for x in range(1, 41))
timelistDS = json.load(datasize)
print(iterlistDS)
print(timelistDS)
datasize.close()
# Out:
# [250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500, 7750, 8000, 8250, 8500, 8750, 9000, 9250, 9500, 9750, 10000]
# [0, 8, 16, 23, 31, 39, 47, 55, 62, 70, 79, 85, 93, 102, 110, 117, 124, 132, 141, 149, 156, 165, 171, 181, 186, 194, 204, 215, 218, 225, 234, 244, 251, 255, 266, 281, 285, 290, 300, 304]

# %%
plt.plot(iterlistDS, timelistDS, color="red", label="increasing data sentence size")
plt.plot(iterlistDN, timelistDN, color="blue", label="increasing data sentence number")
plt.legend()
plt.xlabel("n characters")
plt.ylabel("Time(ms)")
# Out:
# Text(0, 0.5, 'Time(ms)')

# %%
filenumber = open("./analysis/filenumber2000.js", "r")
iterlistFN = list(250 * x for x in range(1, 41))
timelistFN = json.load(filenumber)
print(iterlistFN)
print(timelistFN)
filenumber.close()
# Out:
# [250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500, 7750, 8000, 8250, 8500, 8750, 9000, 9250, 9500, 9750, 10000]
# [88, 84, 79, 79, 75, 76, 71, 70, 69, 66, 64, 62, 61, 58, 56, 55, 53, 52, 50, 47, 46, 43, 41, 39, 37, 35, 33, 31, 29, 28, 26, 24, 22, 20, 18, 16, 14, 12, 11, 8]

# %%
filesize = open("./analysis/filesize2000.js", "r")
iterlistFS = list(250 * x for x in range(1, 41))
timelistFS = json.load(filesize)
print(iterlistFN)
print(timelistFN)
filesize.close()
# Out:
# [250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500, 7750, 8000, 8250, 8500, 8750, 9000, 9250, 9500, 9750, 10000]
# [88, 84, 79, 79, 75, 76, 71, 70, 69, 66, 64, 62, 61, 58, 56, 55, 53, 52, 50, 47, 46, 43, 41, 39, 37, 35, 33, 31, 29, 28, 26, 24, 22, 20, 18, 16, 14, 12, 11, 8]

# %%
plt.plot(iterlistFS, timelistFS, color="red", label="increasing file sentence size")
plt.plot(iterlistFN, timelistFN, color="blue", label="increasing file sentence number")
plt.legend()
plt.xlabel("n characters")
plt.ylabel("Time(ms)")
# Out:
# Text(0, 0.5, 'Time(ms)')
