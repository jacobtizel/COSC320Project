# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
datanumber = open("./analysis/RKdatanumber2000.json", "r")
iterlistDN = list(250 * x for x in range(1, 41))
timelistDN = json.load(datanumber)
print(iterlistDN)
print(timelistDN)
datanumber.close()
# Out:
# [250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500, 7750, 8000, 8250, 8500, 8750, 9000, 9250, 9500, 9750, 10000]
# [0, 9, 17, 25, 35, 43, 52, 59, 68, 78, 89, 95, 107, 117, 120, 132, 148, 149, 154, 164, 175, 187, 193, 198, 217, 224, 241, 243, 243, 248, 251, 257, 270, 285, 292, 309, 306, 310, 324, 331]

# %%
datasize = open("./analysis/RKdatasize2000.json", "r")
iterlistDS = list(250 * x for x in range(1, 41))
timelistDS = json.load(datasize)
print(iterlistDS)
print(timelistDS)
datasize.close()
# Out:
# [250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500, 7750, 8000, 8250, 8500, 8750, 9000, 9250, 9500, 9750, 10000]
# [0, 8, 15, 23, 31, 38, 46, 54, 62, 70, 77, 86, 95, 110, 116, 120, 126, 133, 140, 149, 156, 163, 172, 178, 186, 196, 207, 217, 218, 227, 234, 245, 249, 262, 266, 273, 280, 288, 294, 303]

# %%
plt.plot(iterlistDS, timelistDS, color="red", label="increasing data sentence size")
plt.plot(iterlistDN, timelistDN, color="blue", label="increasing data sentence number")
plt.legend()
plt.xlabel("n characters")
plt.ylabel("Time(ms)")
# Out:
# Text(0, 0.5, 'Time(ms)')

# %%
filenumber = open("./analysis/RKfilenumber2000.json", "r")
iterlistFN = list(250 * x for x in range(1, 41))
timelistFN = json.load(filenumber)
print(iterlistFN)
print(timelistFN)
filenumber.close()
# Out:
# [250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500, 7750, 8000, 8250, 8500, 8750, 9000, 9250, 9500, 9750, 10000]
# [84, 82, 79, 77, 75, 73, 71, 69, 67, 66, 64, 61, 60, 58, 56, 54, 53, 50, 48, 47, 44, 43, 41, 40, 37, 35, 33, 31, 29, 27, 25, 23, 21, 19, 17, 16, 13, 11, 10, 8]

# %%
filesize = open("./analysis/RKfilesize2000.json", "r")
iterlistFS = list(250 * x for x in range(1, 41))
timelistFS = json.load(filesize)
print(iterlistFN)
print(timelistFN)
filesize.close()
# Out:
# [250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500, 7750, 8000, 8250, 8500, 8750, 9000, 9250, 9500, 9750, 10000]
# [84, 82, 79, 77, 75, 73, 71, 69, 67, 66, 64, 61, 60, 58, 56, 54, 53, 50, 48, 47, 44, 43, 41, 40, 37, 35, 33, 31, 29, 27, 25, 23, 21, 19, 17, 16, 13, 11, 10, 8]

# %%
plt.plot(iterlistFS, timelistFS, color="red", label="increasing file sentence size")
plt.plot(iterlistFN, timelistFN, color="blue", label="increasing file sentence number")
plt.legend()
plt.xlabel("n characters")
plt.ylabel("Time(ms)")
# Out:
# Text(0, 0.5, 'Time(ms)')
