# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
patternandstring = open("./analysis/LCSSpatternanddata5000.json")
iterlistPS = list(250 * x for x in range(0,20))
timelistPS = json.load(patternandstring)
print(iterlistPS)
print(timelistPS)
patternandstring.close()
# Out:
# [0, 250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750]
# [0, 11, 25, 63, 105, 168, 245, 355, 469, 580, 718, 936, 1087, 1306, 1473, 1667, 1801, 1929, 2123, 2431]

# %%
plt.plot(iterlistPS,timelistPS, color="red", label="increasing pattern length and data length")
plt.legend()
plt.xlabel("n characters")
plt.ylabel("time (ms)")
# Out:
# Text(0, 0.5, 'time (ms)')

# %%
randomstring = open("./analysis/LCSSrandomstring50000.json")
iterlistRS = list(1000 * x for x in range(0,50))
timelistRS = json.load(randomstring)
print(iterlistRS)
print(timelistRS)
randomstring.close()
# Out:
# [0, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 34000, 35000, 36000, 37000, 38000, 39000, 40000, 41000, 42000, 43000, 44000, 45000, 46000, 47000, 48000, 49000]
# [0, 0, 1, 1, 2, 3, 4, 4, 5, 6, 7, 7, 8, 8, 9, 10, 10, 12, 11, 13, 13, 14, 15, 17, 16, 17, 17, 19, 18, 19, 20, 21, 21, 22, 23, 24, 24, 24, 26, 25, 29, 27, 28, 31, 29, 30, 32, 31, 35, 32]

# %%
stringlength = open("./analysis/LCSSstringlength50000.json")
iterlistSL = list(1000 * x for x in range(0,50))
timelistSL = json.load(stringlength)
print(iterlistSL)
print(timelistSL)
stringlength.close()
# Out:
# [0, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 34000, 35000, 36000, 37000, 38000, 39000, 40000, 41000, 42000, 43000, 44000, 45000, 46000, 47000, 48000, 49000]
# [0, 0, 1, 1, 2, 2, 4, 4, 4, 5, 5, 6, 7, 7, 10, 9, 9, 10, 10, 12, 12, 12, 13, 14, 15, 15, 15, 17, 17, 17, 19, 20, 19, 20, 19, 21, 21, 21, 23, 23, 25, 25, 24, 27, 26, 26, 28, 28, 29, 30]

# %%
plt.plot(iterlistRS,timelistRS, color="red", label="repeatedly adding random letters to data")
plt.plot(iterlistSL,timelistSL, color="blue", label="repeatedly adding pattern to data")
plt.legend()
plt.xlabel("n characters")
plt.ylabel("time (ms)")
# Out:
# Text(0, 0.5, 'time (ms)')
