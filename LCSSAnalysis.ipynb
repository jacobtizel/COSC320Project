# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
patternandstring = open("./analysis/LCSSpatternanddata5000.json")
iterlistPS = list(1250 * x for x in range(1,21))
timelistPS = json.load(patternandstring)
print(iterlistPS)
print(timelistPS)
patternandstring.close()
# Out:
# [1250, 2500, 3750, 5000, 6250, 7500, 8750, 10000, 11250, 12500, 13750, 15000, 16250, 17500, 18750, 20000, 21250, 22500, 23750, 25000]
# [0, 6, 21, 51, 87, 135, 202, 291, 379, 477, 634, 812, 909, 1145, 1234, 1393, 1476, 1612, 1792, 2107]

# %%
plt.plot(iterlistPS,timelistPS, color="red", label="increasing pattern length and data length")
plt.legend()
plt.xlabel("n characters")
plt.ylabel("time (ms)")
# Out:
# Text(0, 0.5, 'time (ms)')

# %%
randomstring = open("./analysis/LCSSrandomstring50000.json")
iterlistRS = list(5000 * x for x in range(1,51))
timelistRS = json.load(randomstring)
print(iterlistRS)
print(timelistRS)
randomstring.close()
# Out:
# [5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000, 65000, 70000, 75000, 80000, 85000, 90000, 95000, 100000, 105000, 110000, 115000, 120000, 125000, 130000, 135000, 140000, 145000, 150000, 155000, 160000, 165000, 170000, 175000, 180000, 185000, 190000, 195000, 200000, 205000, 210000, 215000, 220000, 225000, 230000, 235000, 240000, 245000, 250000]
# [0, 0, 1, 1, 2, 3, 3, 4, 5, 5, 6, 7, 7, 8, 9, 10, 12, 11, 11, 12, 13, 14, 15, 15, 16, 19, 17, 18, 18, 19, 19, 23, 21, 22, 22, 23, 29, 24, 26, 26, 27, 29, 28, 28, 29, 31, 30, 31, 31, 33]

# %%
stringlength = open("./analysis/LCSSstringlength50000.json")
iterlistSL = list(5000 * x for x in range(1,51))
timelistSL = json.load(stringlength)
print(iterlistSL)
print(timelistSL)
stringlength.close()
# Out:
# [5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000, 65000, 70000, 75000, 80000, 85000, 90000, 95000, 100000, 105000, 110000, 115000, 120000, 125000, 130000, 135000, 140000, 145000, 150000, 155000, 160000, 165000, 170000, 175000, 180000, 185000, 190000, 195000, 200000, 205000, 210000, 215000, 220000, 225000, 230000, 235000, 240000, 245000, 250000]
# [0, 1, 1, 2, 2, 3, 3, 4, 5, 5, 6, 6, 7, 8, 8, 9, 10, 10, 11, 11, 12, 13, 13, 14, 14, 16, 16, 15, 17, 17, 19, 21, 20, 20, 21, 21, 24, 21, 23, 23, 24, 26, 25, 26, 27, 28, 29, 29, 28, 30]

# %%
plt.plot(iterlistRS,timelistRS, color="red", label="repeatedly adding random letters to data")
plt.plot(iterlistSL,timelistSL, color="blue", label="repeatedly adding pattern to data")
plt.legend()
plt.xlabel("n characters")
plt.ylabel("time (ms)")
# Out:
# Text(0, 0.5, 'time (ms)')
